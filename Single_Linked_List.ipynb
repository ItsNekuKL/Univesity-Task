# %% [markdown]
# <a href="https://colab.research.google.com/github/ItsNekuKL/Univesity-Task/blob/main/Single_Linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Membuat Contoh Linked List Berukusan 3 untuk Memahai Cara Kerjanya

# %% [markdown]
# 1.   Buat node pertama
#
# *   Alokasikan memori untuk node pertama dan simpan data di dalamnya.
# *   Tandai node ini sebagai head.
#
# 2.   Buat node kedua
#
#
# *   Alokasikan memori untuk node kedua dan simpan data di dalamnya.
# *   Hubungkan node pertama di sebelahnya dengan node baru ini.
#
# 3. Buat simpul ketiga
#
#
# *   Alokasikan memori untuk node ketiga dan simpan data di dalamnya.
# *   Hubungkan node kedua di sebelah node ini.
# *   Atur nilai next-nya menjadi NULL untuk memastikan bahwa nilai next dari nilai terakhir adalah NULL.*teks yang dimiringkan*

# %%
# Konstruktur untuk menginisialisasi node baru dengan data
class Node:
    def __init__(self, new_data):
        self.data = new_data
        self.next = None

# membuat node pertama (head list)
head = Node(10)

# Menghubungkan node kedua
head.next = Node(20)

# Menghubungkan node ketiga
head.next.next = Node(30)

# menghubungkan node keempat
head.next.next.next = Node(40)

# mencetak linked list
temp = head
while temp is not None:
    print(temp.data, end=" ")
    temp = temp.next
# Out:
# 10 20 30 40

# %% [markdown]
# # Penelusuran Daftar Berantai Tunggal (Pendekatan Iteratif)

# %% [markdown]
# **Algoritma Langkah demi Langkah**
#
#
#
# *   Kita akan menginisialisasi pointer sementara ke node kepala dari linked list tunggal.
#
# *   Setelah itu, kita akan memeriksa apakah pointer tersebut null atau tidak null, jika null maka kembalikan nilai.
#
#
# *   Selama penunjuk tidak null, kita akan mengakses dan mencetak data dari node saat ini, kemudian kita memindahkan penunjuk ke node berikutnya.

# %%
# a linked list node
class Node:

    # constructor to initialize a new node with data
    def __init__(self, new_data):
        self.data = new_data
        self.next = None

# function to traverse and print the singly linked list
def traverseList(head):
    while head is not None:
        print(head.data, end="")
        if head.next is not None:
            print(" -> ", end="")
        head = head.next
    print()

if __name__ == "__main__":

    # create a hard-coded linked list:
    # 10 -> 20 -> 30 -> 40
    head = Node(10)
    head.next = Node(20)
    head.next.next = Node(30)
    head.next.next.next = Node(40)

    traverseList(head)
# Out:
# 10 -> 20 -> 30 -> 40

# %% [markdown]
# Kompleksitas Waktu: O(n), di mana n adalah jumlah node dalam linked list. Ruang Tambahan: O(1)

# %% [markdown]
# # Penelusuran Daftar Berantai Tunggal (Pendekatan Rekursif)

# %% [markdown]
# **Algoritma Langkah demi Langkah:**
#
#
#
# *   Pertama, kita mendefinisikan metode rekursif untuk menelusuri linked list tunggal, yang mengambil sebuah node sebagai parameter.
#
# *   Dalam fungsi ini, kasus dasarnya adalah jika node bernilai null maka kita akan keluar dari metode rekursif.
#
#
# *   Kemudian, kita meneruskan node kepala sebagai parameter ke fungsi ini.
#
# *   Setelah itu, kita mengakses dan mencetak data dari node saat ini.
#
#
# *   Terakhir, kita akan melakukan panggilan rekursif ke fungsi ini dengan node berikutnya sebagai parameter.

# %%
# a linked list node
class Node:
    def __init__(self, data):
        # constructor to initialize a new node with data
        self.data = data
        self.next = None

# function to traverse and print the singly linked list
def traverseList(head):
    # base condition is when the head is None
    if head is None:
        print()
        return

    # printing the current node data
    print(head.data, end="")

    # print arrow if not the last node
    if head.next is not None:
        print(" -> ", end="")

    # moving to the next node
    traverseList(head.next)

if __name__ == "__main__":
    # create a hard-coded linked list:
    # 10 -> 20 -> 30 -> 40
    head = Node(10)
    head.next = Node(20)
    head.next.next = Node(30)
    head.next.next.next = Node(40)

    traverseList(head)

# %% [markdown]
# Kompleksitas Waktu: O(n), di mana n adalah jumlah node dalam linked list. Ruang Tambahan: O(n) karena ruang stack rekursif.

# %% [markdown]
# # Sisipkan Node di Depan Linked List

# %% [markdown]
# **Algoritma:**
#
#
# *   Hubungkan node pertama dari Linked List ke node baru.
#
# *   Hapus head dari node pertama asli pada Linked List.
#
#
# *   Jadikan node baru tersebut sebagai Head dari Linked List.

# %%
# Define a node in the linked list
class Node:
    def __init__(self, x):
        self.data = x
        self.next = None

# Function to insert a new node
# at the beginning of the list
def insertAtFront(head, x):
    newNode = Node(x)
    newNode.next = head
    return newNode

# Function to print the contents
# of the linked list
def printList(head):
    curr = head
    while curr is not None:
        print(curr.data, end="")
        if curr.next is not None:
            print(" -> ", end="")
        curr = curr.next
    print()

if __name__ == "__main__":
    # Create the linked list 2->3->4->5
    head = Node(2)
    head.next = Node(3)
    head.next.next = Node(4)
    head.next.next.next = Node(5)

    # Insert a new node at
    # the front of the list
    x = 1
    head = insertAtFront(head, x)

    # Print the updated list
    printList(head)
# Out:
# 1 -> 2 -> 3 -> 4 -> 5

# %% [markdown]
# Kompleksitas Waktu:  O(1), Kita memiliki pointer ke head dan kita dapat langsung melampirkan node dan memperbarui pointer head. Jadi, kompleksitas waktu untuk memasukkan node pada posisi head adalah O(1).
# Ruang Tambahan:  O(1)

# %% [markdown]
# # Sisipkan Node di Akhir Daftar Tertaut

# %% [markdown]
# **Berikut adalah pendekatan untuk menambahkan node baru di akhir linked list:**
#
#
# *   Buat node baru dan atur pointer next-nya menjadi NULL karena ini akan menjadi node terakhir.
#
# *   Simpan referensi kepala dalam variabel sementara.
#
#
# *   Jika Linked List kosong, jadikan node baru sebagai head dan kembalikan nilai.
#
# *   Jika tidak, telusuri hingga simpul terakhir.
#
#
# *   Ubah penunjuk next pada node terakhir agar menunjuk ke node baru.

# %%
# A linked list node
class Node:
    def __init__(self, x):
        # Constructor to initialize a new node with data
        self.data = x
        self.next = None

# Given the head of a list and an int, appends
# a new node at the end and returns the head.
def insertAtEnd(head, x):
    # Create a new node
    newNode = Node(x)

    # If the Linked List is empty, make
    # the new node as the head and return
    if head is None:
        return newNode

    # Store the head reference in a temporary variable
    last = head

    # Traverse till the last node
    while last.next is not None:
        last = last.next

    # Change the next pointer of the last node
    # to point to the new node
    last.next = newNode

    # Return the head of the list
    return head

# This function prints the contents
# of the linked list starting from the head
def printList(node):
    while node is not None:
        print(node.data, end="")
        if node.next is not None:
            print(" -> ", end="")
        node = node.next
    print()

if __name__ == "__main__":
    # Create a linked list:
    # 1 -> 2 -> 3 -> 4 -> 5
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(4)
    head.next.next.next.next = Node(5)

    head = insertAtEnd(head, 6)

    printList(head)

# %% [markdown]
# Kompleksitas Waktu: O(n) di mana n adalah panjang linked list. Ruang Tambahan: O(1).

# %% [markdown]
# # Sisipkan sebuah node pada posisi tertentu dalam sebuah linked list.

# %% [markdown]
# **Implementasi Langkah Demi Langkah:**
#
#
# *   Inisialisasi sebuah variabel, misalnya `curr` menunjuk ke `head`, dan alokasikan memori ke node baru dengan nilai yang diberikan.
#
# *   Telusuri daftar tertaut menggunakan pointer saat ini hingga node posisi-1.
#
#
# *   Jika next dari curr tidak null, maka pointer next dari node baru akan menunjuk ke next dari node curr.
#
# *   Pointer berikutnya dari node saat ini menunjuk ke node baru.
#
#
# *   Kembalikan elemen pertama dari linked list.

# %%
class Node:
    def __init__(self, x):
        self.val = x
        self.next = None

def insertPos(head, pos, val):

    if pos < 1:
        return head

    # head will change if pos = 1
    if pos == 1:
        newNode = Node(val)
        newNode.next = head
        return newNode

    curr = head

    # Traverse to the node just before the new node
    for i in range(1, pos - 1):
        if curr is None:
            return head
        curr = curr.next

    # If position is greater than number of nodes
    if curr is None:
        return head

    newNode = Node(val)

    # update the next pointers
    newNode.next = curr.next
    curr.next = newNode

    return head

def printList(head):
    curr = head
    while curr:
        print(curr.val, end="")
        if curr.next:
            print(" -> ", end="")
        curr = curr.next
    print()

if __name__ == "__main__":
    # Creating the list 1->2->4
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(4)

    val, pos = 3, 3
    head = insertPos(head, pos, val)
    printList(head)
# Out:
# 1 -> 2 -> 3 -> 4

# %% [markdown]
# # Penghapusan di awal (Penghapusan node pertama) dalam Linked List

# %% [markdown]
# Untuk menghapus node pertama dari sebuah linked list , simpan head saat ini dalam variabel sementara (temp) , pindahkan pointer head ke node berikutnya, hapus node head sementara , dan akhirnya, kembalikan head baru dari linked list tersebut.

# %%
class Node:
    def __init__(self, x):
        self.data = x
        self.next = None


# Delete the head node and return the new head
def deleteHead(head):

    # Check if the list is empty
    if head is None:
        return None

    # Store the current head in a
    # temporary variable
    temp = head

    # Move the head pointer to the next node
    head = head.next

    # Free the memory of the old head node
    # (Python garbage collector will handle it)
    temp = None

    return head


# Function to print the linked list
def printList(curr):
    while curr is not None:
        print(curr.data, end="")
        if curr.next is not None:
            print(" -> ", end="")
        curr = curr.next


if __name__ == "__main__":

    # Create a hard-coded linked list:
    # 8 -> 2 -> 3 -> 1 -> 7
    head = Node(8)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(1)
    head.next.next.next.next = Node(7)

    head = deleteHead(head)
    printList(head)
# Out:
# 2 -> 3 -> 1 -> 7

# %% [markdown]
# Kompleksitas Waktu: O(1), karena operasi penghapusan node kepala dilakukan dalam waktu konstan.
# Kompleksitas Ruang: O(1)

# %% [markdown]
# # Penghapusan di akhir (Penghapusan node terakhir) dalam Linked List

# %% [markdown]
# **Pendekatan langkah demi langkah:**
#
#
# *   Periksa apakah daftar kosong, lalu kembalikan NULL .
#
# *   Jika daftar hanya memiliki satu node, maka hapus node tersebut dan kembalikan NULL .
#
#
# *   Telusuri daftar untuk menemukan node kedua terakhir.
# => Atur penunjuk next dari node kedua terakhir ke NULL .

# %%
# Node class for the linked list
class Node:
    def __init__(self, x):
        self.data = x
        self.next = None


# Function to remove the last
# node of the linked list
def removeLastNode(head):
    # If the list is empty, return None
    if head is None:
        return None

    # If the list has only one node,
    # delete it and return None
    if head.next is None:
        return None

    # Find the second last node
    secondLast = head
    while secondLast.next.next is not None:
        secondLast = secondLast.next

    # Delete the last node by making
    # second_last point to None
    secondLast.next = None

    return head


def printList(head):
    while head is not None:
        print(f"{head.data} -> ", end="")
        head = head.next
    print("None")


if __name__ == "__main__":
    # Creating a static linked list
    # 1 -> 2 -> 3 -> 4 -> 5 -> None
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(4)
    head.next.next.next.next = Node(5)

    # Removing the last node
    head = removeLastNode(head)

    printList(head)
# Out:
# 1 -> 2 -> 3 -> 4 -> None

# %% [markdown]
# **Kompleksitas Waktu**: O(n), penelusuran linked list hingga akhir, sehingga kompleksitas waktu yang dibutuhkan adalah O(n) .
#
# **Ruang Tambahan**: O(1)

# %% [markdown]
# # Hapus Node berdasarkan Posisi

# %% [markdown]
# **[Pendekatan] Penghapusan Traversal Tunggal - Waktu O(n) dan Ruang O(1)**
# Penghapusan pada posisi tertentu
#
# *   Penghapusan pada posisi tertentu dalam linked list melibatkan penghapusan node dari indeks/posisi tertentu, yang bisa berupa node pertama, tengah, atau terakhir.
#
#
# *   Untuk melakukan penghapusan, jika posisinya adalah 1, kita memperbarui head agar menunjuk ke node berikutnya dan menghapus head saat ini. Untuk posisi lain, kita menelusuri daftar untuk mencapai node tepat sebelum posisi yang ditentukan . Jika node target ada, kita menyesuaikan next dari node sebelumnya agar menunjuk ke next dari node berikutnya , yang akan mengakibatkan node target dilewati.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def deleteNode(head, position):
    temp = head

    # Head is to be deleted
    if position == 1:
        head = temp.next
        return head

    # Traverse to the node before
    # the one to be deleted
    prev = None
    for i in range(1, position):
        prev = temp
        temp = temp.next

    # Delete the node at the position
    prev.next = temp.next
    return head


def printList(head):
    while head is not None:
        print(f"{head.data} -> ", end="")
        head = head.next
    print("nullptr")


if __name__ == "__main__":
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(4)

    position = 3
    head = deleteNode(head, position)

    printList(head)
# Out:
# 1 -> 2 -> 4 -> nullptr

# %% [markdown]
# # Mencari elemen dalam Linked List

# %% [markdown]
# **[Pendekatan 1] Pendekatan Iteratif - Waktu O(n) dan Ruang O(1)**
# Idenya adalah untuk menelusuri semua node dari linked list, dimulai dari head . Saat menelusuri, jika kita menemukan node yang nilainya sama dengan key, maka cetak "Ya", jika tidak, cetak "Tidak".
#
#
# **Pendekatan Langkah demi Langkah**
# *   Inisialisasi penunjuk node, curr = head .
# * Lakukan hal berikut selama nilai saat ini tidak NULL, Jika nilai saat ini (yaitu, curr->key ) sama dengan kunci yang dicari, kembalikan true, Jika tidak, pindah ke node berikutnya ( curr = curr->next ).
# * Jika kunci tidak ditemukan, kembalikan false.

# %%
# a Linked List Node
class Node:

  	# constructor to intialize a node with data
    def __init__(self, x):
        self.data = x
        self.next = None

# checks whether key is present in linked list
def search_key(head, key):

    # initialize curr with the head of linked list
    curr = head

    # iterate over all the nodes
    while curr is not None:

        # if the current node's value is equal to key,
        # return true
        if curr.data == key:
            return True

        # move to the next node
        curr = curr.next

    # if there is no node with value as key, return false
    return False

if __name__ == "__main__":

    # create a hard-coded linked list:
    # 1 -> 2 -> 3 -> 4 -> 5
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(4)
    head.next.next.next.next = Node(5)

    # key to search in the linked list
    key = 5

    if search_key(head, key):
        print("true")
    else:
        print("false")
# Out:
# true

# %% [markdown]
# **[Pendekatan 2] Pendekatan Rekursif - Waktu O(n) dan Ruang O(n)**
# Ide dasarnya adalah menelusuri semua node secara rekursif mulai dari head (kepala) linked list. Untuk setiap node, jika nilainya sama dengan key , maka kembalikan true. Jika tidak, cari node berikutnya secara rekursif. Jika pada titik tertentu head mencapai NULL , itu berarti kita telah mencapai akhir linked list, jadi kembalikan false .
#
# **Pendekatan Langkah demi Langkah**
#
#
# *   Jika head bernilai NULL, kembalikan false.
# *   Jika kunci kepala sama dengan X , kembalikan true;
# *   Jika tidak, lakukan pencarian rekursif pada node berikutnya.

# %%
# a Linked List Node
class Node:

  	# constructor to initialize a new node with data
    def __init__(self, x):
        self.data = x
        self.next = None

# checks whether the key is present in linked list
def searchKey(head, key):

    # base case
    if head is None:
        return False

    # if key is present in current node, return true
    if head.data == key:
        return True

    # recur for remaining list
    return searchKey(head.next, key)

if __name__ == "__main__":

    # create a hard-coded linked list:
    # 1 -> 2 -> 3 -> 4 -> 5
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(4)
    head.next.next.next.next = Node(5)

    # key to search in the linked list
    key = 5

    if searchKey(head, key):
        print("true")
    else:
        print("false")

# %% [markdown]
# # Membalikkan Daftar Tertaut

# %% [markdown]
# **[Pendekatan] Menggunakan Metode Iteratif - Waktu O(n) dan Ruang O(1)** Idenya adalah membalikkan linked list dengan mengubah arah tautan menggunakan tiga pointer: prev, curr, dan next. Pada setiap langkah, arahkan node saat ini ke node sebelumnya, lalu gerakkan ketiga pointer ke depan hingga linked list sepenuhnya terbalik.

# %%
class Node:
    def __init__(self, newData):
        self.data = newData
        self.next = None

def reverseList(head):

    curr = head
    prev = None

    # traverse all the nodes of Linked List
    while curr is not None:

        # store next
        nextNode = curr.next

        # reverse current node's next pointer
        curr.next = prev

        # move pointers one position ahead
        prev = curr
        curr = nextNode

    return prev


def printList(node):
    while node is not None:
        print(f"{node.data}", end="")
        if node.next is not None:
            print(" -> ", end="")
        node = node.next
    print()


if __name__ == "__main__":

    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(4)
    head.next.next.next.next = Node(5)
    head = reverseList(head)
    printList(head)

# %% [markdown]
# **[Alternate Approach 1] Using Recursion Method- O(n) Time and O(n) Space**
# Ide dasarnya adalah menggunakan rekursi untuk mencapai node terakhir dari daftar, yang menjadi kepala baru setelah pembalikan. Saat rekursi mulai kembali, setiap node membuat node berikutnya menunjuk kembali ke dirinya sendiri, secara efektif membalikkan tautan satu per satu hingga seluruh daftar dibalik.

# %%
class Node:
    def __init__(self, newData):
        self.data = newData
        self.next = None

def reverseList(head):
    if head is None or head.next is None:
        return head

    # reverse the rest of linked list and put the
    # first element at the end
    rest = reverseList(head.next)

    # make the current head as last node of
    # remaining linked list
    head.next.next = head

    # update next of current head to NULL
    head.next = None

    return rest


def printList(node):
    while node is not None:
        print(f"{node.data}", end="")
        if node.next is not None:
            print(" -> ", end="")
        node = node.next
    print()


if __name__ == "__main__":

    # Create a hard-coded linked list:
    # 1 -> 2 -> 3 -> 4 -> 5
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(4)
    head.next.next.next.next = Node(5)

    head = reverseList(head)
    printList(head)

# %% [markdown]
# **[Pendekatan Alternatif 2] Menggunakan Stack - Waktu O(n) dan Ruang O(n)**
#
# Idenya adalah untuk menelusuri linked list dan memasukkan semua node kecuali node terakhir ke dalam stack . Jadikan node terakhir sebagai head yang baru.dari linked list terbalik. Sekarang, mulailah mengeluarkan elemen dan menambahkan setiap node ke linked list terbalik. Terakhir, kembalikan head dari linked list terbalik.

# %%
class Node:
    def __init__(self, new_data):

        self.data = new_data
        self.next = None


def reverseList(head):

    stack = []

    temp = head

    # push all nodes except the last node into stack
    while temp.next is not None:
        stack.append(temp)
        temp = temp.next

    head = temp

    # pop all the nodes and append to the linked list
    while stack:

        # append the top value of stack in list
        temp.next = stack.pop()

        temp = temp.next

    temp.next = None

    return head


def printList(node):
    while node is not None:
        print(f"{node.data}", end="")
        if node.next is not None:
            print(" -> ", end="")
        node = node.next
    print()

if __name__ == "__main__":
    # create a hard-coded linked list:
    # 1 -> 2 -> 3 -> 4 -> 5
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(4)
    head.next.next.next.next = Node(5)

    head = reverseList(head)
    printList(head)

# %% [markdown]
# # Tugas 1

# %% [markdown]
# Anda diberikan elemen pertama dari sebuah Linked List tunggal dan sebuah nilai x , masukkan nilai x tersebut di awal Linked List dan kembalikan elemen pertama dari Linked List yang telah dimodifikasi.
# ![Soal-1.png](data:image/png;base64,...)
#
# Batasan:
# 1 ≤ jumlah node ≤ 10⁵ 1
# ≤ node->data, x ≤ 10³

# %% [markdown]
# Lengkapi kode di bawah untuk menjawab soal 1

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class Solution:
    def insertAtFront(self, head, x):
        #Jawaban disini
# Out:
#   File "/tmp/ipykernel_8216/2171198556.py", line 9
#
#     ^
# SyntaxError: incomplete input

# %% [markdown]
# # Tugas 2

# %% [markdown]
# Anda diberikan elemen pertama dari sebuah linked list tunggal . Kembalikan sebuah array yang berisi nilai-nilai dari node-node tersebut.
# ![Soal-2.png](data:image/png;base64,...)
#
# Batasan:
# 1 ≤ jumlah node ≤ 10 5
# 1 ≤ nilai node ≤ 10

# %%
class Node:
    def __init__(self, x):
        self.data = x
        self.next = None

class Solution:
    def printList(self, head):
        #Jawaban disini
# Out:
#   File "/tmp/ipykernel_8216/1690094341.py", line 8
#     #Jawaban disini
#                    ^
# SyntaxError: incomplete input

# %% [markdown]
# # Tugas 3

# %% [markdown]
# Anda diberikan elemen pertama dari sebuah Linked List tunggal dan sebuah nilai x , masukkan nilai x tersebut di awal Linked List dan kembalikan elemen pertama dari Linked List yang telah dimodifikasi.
#
# ![Soal-3.png](data:image/png;base64,...)
#
# Batasan:
# 1 ≤ jumlah node ≤ 10⁵ 1
# ≤ node->data, x ≤ 10³

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.next = None

class Solution:
    def insertAtFront(self, head, x):
        #jawaban disini

# %% [markdown]
# # Tugas 4

# %% [markdown]
# Anda diberikan elemen pertama dari sebuah Linked List tunggal dan sebuah nilai x , masukkan nilai x tersebut di akhir Linked List dan kembalikan elemen pertama dari Linked List yang telah dimodifikasi.
#
# ![image.png](data:image/png;base64,...)
#
# 0 ≤ jumlah node ≤ 10⁵ 0
# ≤ node->data, x ≤ 10³

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class Solution:
    def insertAtEnd(self, head, x):
        #jawaban disini

# %% [markdown]
# # Tugas 5

# %% [markdown]
# Diberikan sebuah Linked List, hapus ekor (yaitu, node terakhir) dari Linked List tersebut dan kembalikan kepala baru dari Linked List yang telah dimodifikasi .
#
# ![image.png](data:image/png;base64,...)
#
# Batasan:
# 1 ≤ jumlah  node  ≤  10⁵
# 1 ≤ node->data ≤ 10⁵

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class Solution:
    def removeLastNode(self, head):
        # code here
